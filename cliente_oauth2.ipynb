# %%
#crear claves asimetricas

from Crypto.PublicKey import RSA

key = RSA.generate(2048)
pv_key_string = key.exportKey()
publicPem=str()

with open ("private1.pem", "w") as prv_file:
    print("{}".format(pv_key_string.decode()), file=prv_file)

pb_key_string = key.publickey().exportKey()
with open ("public1.pem", "w") as pub_file:
    print("{}".format(pb_key_string.decode()), file=pub_file)
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAwxC4ogaD7W9e/5WJQXvu
# 4vU2vaf4qnD0f2jbhYE0Bc5Emv6PILlZAjy7l33+iEjxZ5AmRAxnkPBpYhc0PvEE
# YqiwiM51+oCO3PoKgIJKbXh63qAFKBbxbme6YSV84sg6j1Yjk4z1GmWUCy1idlYb
# GPQ+SqJqr/UDwD2ATLnz/z+RsKUUpIHHu7Lhbpe2xCZCXFKhsYzBEn5CNeNVxw8I
# 1q9dHImgjYWp1iK/l1cgOlgqlWEKL3PIqP+Rm+92eMp9aw6rkBo9tgBSG0feSXv6
# 27BiwYtdKh/jWUbkTIVUrMa2V93qbPkAUDxUdAx7P154xS11rFF7crXPwZWMtTHo
# 9wIDAQAB
# -----END PUBLIC KEY-----
#
# -----BEGIN RSA PRIVATE KEY-----
# MIIEpAIBAAKCAQEAwxC4ogaD7W9e/5WJQXvu4vU2vaf4qnD0f2jbhYE0Bc5Emv6P
# ILlZAjy7l33+iEjxZ5AmRAxnkPBpYhc0PvEEYqiwiM51+oCO3PoKgIJKbXh63qAF
# KBbxbme6YSV84sg6j1Yjk4z1GmWUCy1idlYbGPQ+SqJqr/UDwD2ATLnz/z+RsKUU
# pIHHu7Lhbpe2xCZCXFKhsYzBEn5CNeNVxw8I1q9dHImgjYWp1iK/l1cgOlgqlWEK
# L3PIqP+Rm+92eMp9aw6rkBo9tgBSG0feSXv627BiwYtdKh/jWUbkTIVUrMa2V93q
# bPkAUDxUdAx7P154xS11rFF7crXPwZWMtTHo9wIDAQABAoIBAGFaQwt6PPWPE9Zz
# ByGLfNoAj+Vvo4dNAHlmF8k1hoUvQMYqLbyjRGz9apJc61+RKAoLw01K85U+pxmx
# ...

# %%
#Mostrar los archivos de claves
publicPem=str()
privatePem=str()
with open ("public1.pem", "r") as pub_file:
    #print(pub_file.read())
    publicPem=pub_file.read()
with open ("private1.pem", "r") as pub_file:
    #print(pub_file.read())
    privatePem=pub_file.read()
print(publicPem)
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAwxC4ogaD7W9e/5WJQXvu
# 4vU2vaf4qnD0f2jbhYE0Bc5Emv6PILlZAjy7l33+iEjxZ5AmRAxnkPBpYhc0PvEE
# YqiwiM51+oCO3PoKgIJKbXh63qAFKBbxbme6YSV84sg6j1Yjk4z1GmWUCy1idlYb
# GPQ+SqJqr/UDwD2ATLnz/z+RsKUUpIHHu7Lhbpe2xCZCXFKhsYzBEn5CNeNVxw8I
# 1q9dHImgjYWp1iK/l1cgOlgqlWEKL3PIqP+Rm+92eMp9aw6rkBo9tgBSG0feSXv6
# 27BiwYtdKh/jWUbkTIVUrMa2V93qbPkAUDxUdAx7P154xS11rFF7crXPwZWMtTHo
# 9wIDAQAB
# -----END PUBLIC KEY-----

# %%
from cryptography.hazmat.primitives import serialization

def deserialize_private_key(pem_key):
    try:
        private_key = serialization.load_pem_private_key(pem_key, password=None)
        return private_key
    except Exception as e:
        print("Error deserializing private key:", str(e))
        return None

# Example usage:
pem_private_key = """
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY----- """

print(type(pem_private_key))
print("aaa:",pem_private_key)
print("____________")
print(type(privatePem))
print("bbbb:",privatePem)


private_key = deserialize_private_key(privatePem.encode())

if private_key:
    # Now you can use the private_key object for cryptographic operations.
    print("Private key deserialized successfully!")
else:
    print("Failed to deserialize the private key.")
# Out:
# <class 'str'>
# aaa:
# -----BEGIN RSA PRIVATE KEY-----
# MIIEpAIBAAKCAQEAwxC4ogaD7W9e/5WJQXvu4vU2vaf4qnD0f2jbhYE0Bc5Emv6P
# ILlZAjy7l33+iEjxZ5AmRAxnkPBpYhc0PvEEYqiwiM51+oCO3PoKgIJKbXh63qAF
# KBbxbme6YSV84sg6j1Yjk4z1GmWUCy1idlYbGPQ+SqJqr/UDwD2ATLnz/z+RsKUU
# pIHHu7Lhbpe2xCZCXFKhsYzBEn5CNeNVxw8I1q9dHImgjYWp1iK/l1cgOlgqlWEK
# L3PIqP+Rm+92eMp9aw6rkBo9tgBSG0feSXv627BiwYtdKh/jWUbkTIVUrMa2V93q
# bPkAUDxUdAx7P154xS11rFF7crXPwZWMtTHo9wIDAQABAoIBAGFaQwt6PPWPE9Zz
# ByGLfNoAj+Vvo4dNAHlmF8k1hoUvQMYqLbyjRGz9apJc61+RKAoLw01K85U+pxmx
# gv22w/2JOzHL+M2gw6w9jmg8nnCsJIZfTrOHX88+LaK2VvHIBJHs56yIOPuHnq9F
# Y1Kz/qohm8Ub8isHGWwkRZgFZmUIsLKdK4cgXIKn9PW3xa5sR3w7kyunx85Aw2Ln
# epYIJnoovGdNt7Z1i7LGdkRvX6lcQ4Tv4aQIhJwl3JA5S+VW2jsA6NPVt75NGGLu
# a1U5MUUMD+jTAScoYQFnWv8bBwOskkK9p+HLh3VJ/Fkx7iRNxqAnatm62OGx/EQL
# UvDgXYECgYEAydKxhLqqyBvYtnWAO1HFlR0XvCSe2djKiV+aCoOsCIB8sZutkGQ+
# IeRWyUb1q4/5W+gM5c/X/wdV8kMsNDt8JeirNaQXlB9x5C7gA3y9Sx9CYNQ+/Knt
# eAOSskKf2xwp7cRJhN1bCduWYKKcReehKqCglmc4Fmv7mTRPmhTWp5ECgYEA922j
# ...

# %%
# Crear JWK a partir de una clave pública PEM.
#### el JWK se entrega al servidor de autenticación/autorización al momento de creación del registro del cliente.
import base64
import hashlib
import json
from cryptography.hazmat.primitives import serialization
from math import ceil
from datetime import datetime, timedelta

def pem_to_jwk(pem_public_key):
    # Cargar la clave pública desde el formato PEM
    public_key = serialization.load_pem_public_key(pem_public_key.encode(), backend=None)

    # Obtener los componentes de la clave pública
    e = public_key.public_numbers().e
    n = public_key.public_numbers().n

    # Construir el objeto JWK
    jwk = {
        "kty": "RSA",
        "e": base64.urlsafe_b64encode(e.to_bytes(ceil(e.bit_length() / 8))).decode().rstrip('='),
        "use": "sig",  # Use "sig" para firmar o "enc" para cifrar
        "kid": generate_kid(pem_public_key),
        "alg": "RS384",  # Algoritmo de firma (puedes cambiarlo si es necesario)
        "n": base64.urlsafe_b64encode(n.to_bytes(ceil(n.bit_length() / 8))).decode().rstrip('=')
    }

    return jwk

def generate_kid(pem_public_key):
    # Calcular el hash SHA-256 de la clave pública para obtener el kid
    public_key = serialization.load_pem_public_key(pem_public_key.encode(), backend=None)
    sha256_hash = hashlib.sha256(public_key.public_bytes(
        encoding=serialization.Encoding.PEM,
        format=serialization.PublicFormat.SubjectPublicKeyInfo
    )).digest()

    # Tomar los primeros 16 caracteres del hash como kid
    kid = base64.urlsafe_b64encode(sha256_hash)[:16].decode()

    return kid

# Ejemplo de uso:
pem_public_key = publicPem

jwk = pem_to_jwk(pem_public_key)
print(json.dumps(jwk, indent=2))
# Out:
# {
#   "kty": "RSA",
#   "e": "AQAB",
#   "use": "sig",
#   "kid": "a9-Y3E_cts92xqPp",
#   "alg": "RS384",
#   "n": "wxC4ogaD7W9e_5WJQXvu4vU2vaf4qnD0f2jbhYE0Bc5Emv6PILlZAjy7l33-iEjxZ5AmRAxnkPBpYhc0PvEEYqiwiM51-oCO3PoKgIJKbXh63qAFKBbxbme6YSV84sg6j1Yjk4z1GmWUCy1idlYbGPQ-SqJqr_UDwD2ATLnz_z-RsKUUpIHHu7Lhbpe2xCZCXFKhsYzBEn5CNeNVxw8I1q9dHImgjYWp1iK_l1cgOlgqlWEKL3PIqP-Rm-92eMp9aw6rkBo9tgBSG0feSXv627BiwYtdKh_jWUbkTIVUrMa2V93qbPkAUDxUdAx7P154xS11rFF7crXPwZWMtTHo9w"
# }

# %%
#Crear client assertion firmando el JWT con clave privada

import jwt
import time

import timedelta
from datetime import datetime, timedelta

def create_client_assertion(client_id, private_key_path, token_endpoint):
    # Leer el contenido de la clave privada
    #with open(private_key_path, 'r') as f:
        
    # Crear el payload para el JWT
    iat = int(time.time())
    exp = iat + 3600  # El token expirará en 1 hora (3600 segundos)
    payload = {
        "iss": client_id,
        "sub": client_id,
        "aud": token_endpoint,
        "iat": iat,
        "exp": datetime.utcnow()+timedelta(minutes=4)
    }

    # Crear el client_assertion JWT utilizando la clave privada
    client_assertion = jwt.encode(payload, private_key, algorithm='RS384')

    return client_assertion

# Ejemplo de uso:
#El Client ID lo entrega el servidor de autenticación, al momento de crear el registro del cliente en el sistema
client_id = "8bc6bc6d-2da5-424b-be6a-d0491dd1c6ce"

private_key= privatePem
token_endpoint = "http://localhost:8080/openid-connect-server-webapp/token" # este es el endpoint del servidor de autorización

client_assertion = create_client_assertion(client_id, private_key, token_endpoint)
print("Client Assertion JWT:", client_assertion)
#print(client_assertion.decode('utf-8'))
# Out:
# Client Assertion JWT: eyJhbGciOiJSUzM4NCIsInR5cCI6IkpXVCJ9.eyJpc3MiOiI4YmM2YmM2ZC0yZGE1LTQyNGItYmU2YS1kMDQ5MWRkMWM2Y2UiLCJzdWIiOiI4YmM2YmM2ZC0yZGE1LTQyNGItYmU2YS1kMDQ5MWRkMWM2Y2UiLCJhdWQiOiJodHRwOi8vbG9jYWxob3N0OjgwODAvb3BlbmlkLWNvbm5lY3Qtc2VydmVyLXdlYmFwcC90b2tlbiIsImlhdCI6MTY5MTEzMTk5NywiZXhwIjoxNjkxMTMyMjM3fQ.mVEItN1AHsy46y24tX6tVTeiIICbyI45C7bCJ_kVT7ayTUwGlTRC9Peyzru0YLffbNLJNIKOu7TiPNSDlll_KRwdKy6PEUg3k746ywuvkGPfbUBg7oIRnkS7CU520-6Tp7H35ngupyU5KK3gG5PgwFWhXSdwR0W_9tRY5cThGKhhjcmP7eZ2Zl78RgAu2hTya1TDLal1VgtsbTbmeC151DCIxQbAeAblbxx7_aC1Sgl6kS4doj9_NN-8s9bIQ8eV_J0H52gpGCC27qJRJKAbjtsAreV-b5Bw5W0smGUtBkVytQzBbt-TLjr9pGxJYDp3ZhQrJhMYH-HRNtWBut5Hng

# %%
# Preparar Request con los headers y el body que incluye el client_assertion


import requests

def make_token_request():
    url = 'http://localhost:8080/openid-connect-server-webapp/token'
    headers = {
        'accept': 'application/json',
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    data = {
        'grant_type': 'client_credentials',
        'scope': 'profile',
        'client_assertion_type': 'urn:ietf:params:oauth:client-assertion-type:jwt-bearer',
        'client_assertion': client_assertion
    }

    response = requests.post(url, headers=headers, data=data)

    if response.status_code == 200:
        token_data = response.json()
        access_token = token_data.get('access_token')
        
        print("Access Token:", access_token)
        return access_token
    else:
        print(f"Error en la solicitud: {response.status_code} - {response.text}")
    


# Ejecutar Request.
access_token=make_token_request()
# Out:
# Access Token: eyJraWQiOiJyc2ExIiwiYWxnIjoiUlMyNTYifQ..fQ3TPaFYwqg56iaFBgwNOBBsz-mSvft04vjh-H7G8GR--WRyupVZxRqFtkOvjCTv92nGQig6q1AVHuqKS5A-omwlnVblh_loPvehB4QsAgi5Ouw2cKJLZ0XMrEPRejaFhEQ4-XR72MJkm6LNz05I11CZG7OAw-Y5ownBgRetO7d6xUPyJZtO7Pvtbrf1K1ARBPXULrN2G-5HU7vLIBYPCqeQz4VLaWydy6kJdAFV0j7SwLJVyMhxRmdFiURJuq4mybttiZNl6thf6f7ecsZCDTxv8tjqfcDup2G7UOknKNs3iMgIn9YY_b3Vuh_gDL-BFVt2VPDmI5W20Xh6-a09jA

# %%
import requests

def introspect_token(token, token_type_hint="Bearer", client_id=None, client_secret=None, introspection_url=None):
    if not introspection_url:
        raise ValueError("La URL de introspección no está especificada.")

    data = {
        "token": token,
        "token_type_hint": token_type_hint,
        "Authorization": "Bearer"
         
    }
    
    headers={
        "accept": "application/json",
        "Content-Type": "application/x-www-form-urlencoded",
        "Authorization": "Bearer"
    }

    #if client_id and client_secret:
    #    data["client_id"] = client_id
    #    data["client_secret"] = client_secret
    """POST /introspect HTTP/1.1
    Host: server.example.com
    Accept: application/json
    Content-Type: application/x-www-form-urlencoded
    Authorization: Bearer 23410913-abewfq.123483

    token=2YotnFZFEjr1zCsicMWpAA
    """

    print(data)
    response = requests.post(introspection_url, data=data,headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        raise ValueError("Error en la solicitud de introspección. Código de respuesta: {}, Contenido: {}".format(response.status_code, response.text))

# Ejemplo de uso:
introspection_url = "http://localhost:8080/openid-connect-server-webapp/introspect"
#client_id = "mi_cliente_id"
#client_secret = "mi_cliente_secreto"
#access_token = "mi_token_de_acceso"
introspection_result = introspect_token(access_token, client_id=client_id, client_secret=client_secret, introspection_url=introspection_url)
print(introspection_result)
# Out:
# {'token': 'eyJraWQiOiJyc2ExIiwiYWxnIjoiUlMyNTYifQ..fQ3TPaFYwqg56iaFBgwNOBBsz-mSvft04vjh-H7G8GR--WRyupVZxRqFtkOvjCTv92nGQig6q1AVHuqKS5A-omwlnVblh_loPvehB4QsAgi5Ouw2cKJLZ0XMrEPRejaFhEQ4-XR72MJkm6LNz05I11CZG7OAw-Y5ownBgRetO7d6xUPyJZtO7Pvtbrf1K1ARBPXULrN2G-5HU7vLIBYPCqeQz4VLaWydy6kJdAFV0j7SwLJVyMhxRmdFiURJuq4mybttiZNl6thf6f7ecsZCDTxv8tjqfcDup2G7UOknKNs3iMgIn9YY_b3Vuh_gDL-BFVt2VPDmI5W20Xh6-a09jA', 'token_type_hint': 'Bearer', 'Authorization': 'Bearer'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 45
# ...
